# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as snf
import numpy as np

# %%
data=pd.read_csv('/content/Cars.csv')
data.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
data.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.displot(data['HP'])
plt.show()

# %%
sns.displot(data['MPG'])
plt.show()

# %%
sns.displot(data['VOL'])
plt.show()

# %%
sns.displot(data['SP'])
plt.show()

# %%
sns.displot(data['HP'])
plt.show()

# %%
sns.displot(data['HP'])
plt.show()

# %%
sns.displot(data['WT'])
plt.show()

# %%
sns.displot(x=data['WT'])
plt.title('Distribution of weight of vechiles in thousand pounds')
plt.xlabel('Weight in Thousand Pounds')
plt.show()

# %%
sns.displot(x=data['MPG'])
plt.title('Distribution of weight of vechiles in thousand pounds')
plt.xlabel('Weight in Thousand Pounds')
plt.show()

# %%
sns.displot(x=data['SP'])
plt.title('Distribution of weight of vechiles in thousand pounds')
plt.xlabel('Weight in Thousand Pounds')
plt.show()

# %%
sns.displot(x=data['VOL'])
plt.title('Distribution of weight of vechiles in thousand pounds')
plt.xlabel('Weight in Thousand Pounds')
plt.show()

# %%
sns.displot(x=data['WT'])
plt.title('Distribution of weight of vechiles in thousand pounds')
plt.xlabel('Weight in Thousand Pounds')
plt.show()

# %%
sns.boxplot(x=data['VOL'])
plt.show()

# %%
sns.boxplot(x=data['SP'])
plt.show()

# %%
sns.boxplot(x=data['MPG'])
plt.show()

# %%
sns.boxplot(x=data['HP'])
plt.show()

# %%
sns.boxplot(x=data['WT'])
plt.show()

# %%
sns.regplot(x=data['VOL'],y=data['MPG'],data=data)
# Out:
# <Axes: xlabel='VOL', ylabel='MPG'>

# %%
sns.regplot(x=data['SP'],y=data['WT'],data=data)
# Out:
# <Axes: xlabel='SP', ylabel='WT'>

# %%
sns.regplot(x=data['SP'],y=data['MPG'],data=data)
# Out:
# <Axes: xlabel='SP', ylabel='MPG'>

# %%
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>

# %%
data.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
sns.barplot(x=data['HP'],y=data['VOL'],data=data)
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>

# %%
sns.regplot(x=data['HP'],y=data['VOL'],data=data)
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>

# %%
sns.regplot(x=data['HP'],y=data['WT'],data=data)
# Out:
# <Axes: xlabel='HP', ylabel='WT'>

# %%
sns.regplot(x=data['HP'],y=data['SP'],data=data)
# Out:
# <Axes: xlabel='HP', ylabel='SP'>

# %%
sns.scatterplot(x=data['HP'],y=data['VOL'],data=data)
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>

# %%
sns.scatterplot(x=data['HP'],y=data['SP'],data=data)
# Out:
# <Axes: xlabel='HP', ylabel='SP'>

# %%
sns.scatterplot(x=data['HP'],y=data['WT'],data=data)
# Out:
# <Axes: xlabel='HP', ylabel='WT'>

# %%
sns.scatterplot(x=data['WT'],y=data['VOL'],data=data)
# Out:
# <Axes: xlabel='WT', ylabel='VOL'>

# %%
sns.scatterplot(x=data['WT'],y=data['SP'],data=data)
# Out:
# <Axes: xlabel='WT', ylabel='SP'>

# %%
sns.scatterplot(x=data['VOL'],y=data['SP'],data=data)
# Out:
# <Axes: xlabel='VOL', ylabel='SP'>
